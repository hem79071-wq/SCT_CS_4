# %% [markdown]
# <a href="https://colab.research.google.com/github/hem79071-wq/SCT_CS_4/blob/main/basic_keylogger_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Keylogging Simulation (Educational Purpose Only)

print("=== Simple Key Logger Demo ===")
print("Type something and press Enter")
print("Type 'EXIT' to stop\n")

log_file = "key_log.txt"

while True:
    user_input = input("Enter text: ")

    if user_input.upper() == "EXIT":
        print("Logging stopped.")
        break

    with open(log_file, "a") as file:
        file.write(user_input + "\n")
# Out:
# === Simple Key Logger Demo ===
# Type something and press Enter
# Type 'EXIT' to stop
#
# Enter text: Hello internship task
# Enter text: Heloo world
# Enter text: Helloo mummy
# Enter text: EXIT
# Logging stopped.

# %%
# !ls
# Out:
# key_log.txt  sample_data

# %%
# !cat key_log.txt
# Out:
# Hello internship task
# Heloo world
# Helloo mummy
